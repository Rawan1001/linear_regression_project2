# %%
# Scraper for The movieDB website

# %%
from bs4 import BeautifulSoup
import requests
import time, os
from collections import defaultdict
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
# Init. the driver

chromedriver = "/Users/snouto/Downloads/chromedriver" 
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
# Getting the movie info function

def get_movie_info(driver,url):
    driver.get(url)
    results = {}
    bs = BeautifulSoup(driver.page_source,"html5lib")
    genre_element = bs.select("div.facts > span.genres > a")
    user_rating_percentage = bs.find("div",class_="user_score_chart")
    section = bs.find("section",class_="facts left_column")
    if len(genre_element) > 0:
        genres = [x.text for x in genre_element]
        results['genre_count'] = str(len(genres))
        results['genre'] = ",".join(genres)
    if user_rating_percentage:
        results['rating'] = user_rating_percentage.get('data-percent')
    paragraphs = section.select("p")
    keywords_section = bs.find("section",class_="keywords right_column")
    keywords = keywords_section.select("li")
    results['keywords'] = str(len(keywords))
    for p in paragraphs:
        if "Revenue" in p.text:
            results['revenue'] = p.text.replace("Revenue","").replace("$","")
        if "Budget" in p.text:
            results['budget'] = p.text.replace("Budget","").replace("$","")

    return results

# %%
# Starting the scraper 
## (must click the botton Load more for the frist time, then it will be automated) 

movies = defaultdict(dict)
url = "https://www.themoviedb.org/movie"
base_url = "https://www.themoviedb.org"
output_file = "/Users/snouto/Documents/movies/movies2.tsv"
num_scrolls = 250
driver = webdriver.Chrome(chromedriver)
driver.get(url)
for _ in range(num_scrolls):
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
    time.sleep(1)

# %%
bs = BeautifulSoup(driver.page_source, "html5lib")
elements = bs.find_all("div", class_="card style_1")
for element in elements:
    movie = {}
    movie_element = element.find("a", class_="image")
    title = movie_element.get('title')
    url = movie_element.get('href')
    if title in movies:
        # don't add duplicates
        continue
    movies[title]['title'] = title
    movies[title]['url'] = f"{base_url}{url}"
    # element.find("div",class_="content").find("p")
    release_date = element.select("div.content > p")
            # return list of one element (releasa_date)
    if len(release_date) > 0:
        movies[title]['release_date'] = release_date[0].text
print(f"Downloaded : {len(movies.keys())} Movies. Extending Them")
# Out:
# Downloaded : 3253 Movies. Extending Them

# %%
# download more Details for movies
for title, movie in movies.items():
    print(f"Bringing information for movie: {title}")
    movie_details = get_movie_info(driver,movie['url'])
    movies[title].update(movie_details)
# Out:
# Bringing information for movie: Venom: Let There Be Carnage
# Bringing information for movie: Dune
# Bringing information for movie: Halloween Kills
# Bringing information for movie: Free Guy
# Bringing information for movie: Venom
# Bringing information for movie: The Seven Deadly Sins: Cursed by Light
# Bringing information for movie: The Addams Family 2
# Bringing information for movie: Snake Eyes: G.I. Joe Origins
# Bringing information for movie: Matando Cabos 2: La Máscara del Máscara
# Bringing information for movie: Deathstroke: Knights & Dragons - The Movie
# Bringing information for movie: Grudge
# Bringing information for movie: Zone 414
# Bringing information for movie: Pokémon the Movie: Secrets of the Jungle
# Bringing information for movie: Injustice
# Bringing information for movie: After We Fell
# Bringing information for movie: The Last Warrior: Root of Evil
# Bringing information for movie: Shang-Chi and the Legend of the Ten Rings
# Bringing information for movie: The Suicide Squad
# Bringing information for movie: The Boss Baby: Family Business
# Bringing information for movie: Cosmic Sin
# Bringing information for movie: Demon Slayer -Kimetsu no Yaiba- The Movie: Mugen
# Bringing information for movie: The Lion King
# Bringing information for movie: Cell 211
# Bringing information for movie: Justice Society: World War II
# Bringing information for movie: New Gods: Nezha Reborn
# Bringing information for movie: Fury
# Bringing information for movie: The New Mutants
# Bringing information for movie: Boyka: Undisputed IV
# Bringing information for movie: TEKKEN
# Bringing information for movie: Black Island
# Bringing information for movie: Ponyo
# Bringing information for movie: Dawn of the Planet of the Apes
# Bringing information for movie: Below Zero
# Bringing information for movie: The Conjuring 2
# Bringing information for movie: The Island of Giant Insects
# Bringing information for movie: Lokillo: Nothing's the Same
# Bringing information for movie: Porn to Be Free
# Bringing information for movie: Benny Loves You
# Bringing information for movie: Naruto Shippuden the Movie: Road to Ninja
# Bringing information for movie: Weathering with You
# Bringing information for movie: Resort to Love
# Bringing information for movie: San Andreas
# Bringing information for movie: The Ice Road
# Bringing information for movie: Naruto Shippuden the Movie: Blood Prison
# Bringing information for movie: Toy Story 4
# Bringing information for movie: Clash of the Titans
# Bringing information for movie: Earwig and the Witch
# Bringing information for movie: 100% Wolf
# Bringing information for movie: Charlie and the Chocolate Factory
# Bringing information for movie: Thunder Force
# Bringing information for movie: Deadpool 2
# Bringing information for movie: Ratatouille
# Bringing information for movie: Money Heist: The Phenomenon
# Bringing information for movie: The Tax Collector
# Bringing information for movie: John Carter
# Bringing information for movie: Iron Man
# Bringing information for movie: The Voyeurs
# Bringing information for movie: Skyfall
# Bringing information for movie: Dragon Ball Z: Broly – Second Coming
# Bringing information for movie: Prometheus
# Bringing information for movie: The Penitent Thief
# Bringing information for movie: Fifty Shades of Grey
# Bringing information for movie: Big Hero 6
# Bringing information for movie: Machine Gun Preacher
# Bringing information for movie: Space Sweepers
# Bringing information for movie: Ice Age
# Bringing information for movie: We Bare Bears: The Movie
# Bringing information for movie: The 8th Night
# Bringing information for movie: Hotel Transylvania
# Bringing information for movie: John Wick: Chapter 2
# Bringing information for movie: August Never Ends
# Bringing information for movie: Barbie & Chelsea: The Lost Birthday
# Bringing information for movie: Black Panther
# Bringing information for movie: The Proposal
# Bringing information for movie: Aquaslash
# Bringing information for movie: Wrath of the Titans
# Bringing information for movie: Interstellar
# Bringing information for movie: Dragon Ball Z: Broly – The Legendary Super Saiyan
# Bringing information for movie: No me echen ese muerto
# Bringing information for movie: Shazam!
# Bringing information for movie: Dragon Ball Z: Battle of Gods
# Bringing information for movie: Titane
# Bringing information for movie: Maze Runner: The Death Cure
# Bringing information for movie: The Nun
# Bringing information for movie: Bingo Hell
# Bringing information for movie: Fifty Shades Freed
# Bringing information for movie: Angels & Demons
# Bringing information for movie: Yes Man
# Bringing information for movie: We Can Be Heroes
# Bringing information for movie: Twilight
# Bringing information for movie: Captain America: The First Avenger

# %%
# save data to Tab Separated Values
print(f"Saving Results to the output file {output_file}.")
with open(output_file,"w") as writer:
    keys = list(movies.keys())
    headers = list(movies[keys[0]].keys())
    headers = "\t".join(headers)
    writer.write(headers+"\n")
    for title , movie in movies.items():
        row = list(movie.values())
        writer.write("\t".join(row)+"\n")

print("results saved...")
